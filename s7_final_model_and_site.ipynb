# %%
import glob
from catboost.utils import get_gpu_device_count
import pandas as pd
import numpy as np
import random
from sklearn.metrics import mean_absolute_error

# %%
from sklearn.model_selection import train_test_split

# %%
is_gpu_available = get_gpu_device_count()
device = 'GPU' if is_gpu_available else 'CPU'

device
# Out:
# 'CPU'

# %%
np.random.seed(123)
random.seed(123)

# %%
import openpyxl

# %%
df_airports = pd.read_excel("airports.xlsx")

# %%
cities = df_airports['airport'].tolist()
cities = list(map(str.strip, cities))

# %%
n_samples = 300000

# %%
date_range = pd.date_range('2022-01-01', '2024-12-31', freq='D')

# %%
flights = {
    'flight_number': [f'FL{random.randint(100, 999)}' for _ in range(n_samples)],
    'departure_city': np.random.choice(cities, n_samples),
    'arrival_city': np.random.choice(cities, n_samples),
    'departure_time': pd.Timestamp(np.random.choice(date_range)).strftime("%Y-%m-%d"),
    'departure_hour': np.random.randint(0, 24, n_samples)
}
flights_df = pd.DataFrame(flights)

# %%
# Out:
#        flight_number             departure_city             arrival_city  \
# 0              FL153           Томск (Богашево)                   Абакан
# 1              FL374                    Иркутск                  Магадан
# 2              FL189  Санкт-Петербург (Пулково)                   Якутск
# 3              FL887                  Остафьево  Красноярск (Емельяново)
# 4              FL517             Ханты-Мансийск    Нижнекамск (Бегишево)
# ...              ...                        ...                      ...
# 299995         FL919                     Элиста                Махачкала
# 299996         FL832                    Магадан       Тобольск (Ремезов)
# 299997         FL678     Ульяновск (Баратаевка)   Астрахань (Нариманово)
# 299998         FL682                  Махачкала  Екатеринбург (Кольцово)
# 299999         FL499       Москва (Шереметьево)                     Сочи
#
#        departure_time  departure_hour
# 0          2022-11-12              22
# 1          2022-11-12               2
# 2          2022-11-12              13
# 3          2022-11-12              13
# 4          2022-11-12              16
# ...               ...             ...
# 299995     2022-11-12               0
# 299996     2022-11-12               0
# 299997     2022-11-12               6
# 299998     2022-11-12              16
# 299999     2022-11-12               4
#
# [300000 rows x 5 columns]

# %%
flights_df['departure_time'] = pd.to_datetime(flights_df['departure_time'])

# %%
flights_df['is_weekend'] = flights_df['departure_time'].dt.weekday.isin([5, 6]).astype(int)  # 1, если сб/вс
flights_df['season'] = flights_df['departure_time'].dt.month.map(lambda m: 1 if m in [12, 1, 2] else
                                                                            2 if m in [3, 4, 5] else
                                                                            3 if m in [6, 7, 8] else 4)
flights_df['day_of_week'] = flights_df['departure_time'].dt.weekday  # 0 - Пн, 6 - Вс

# %%
flights_df
# Out:
#        flight_number             departure_city             arrival_city  \
# 0              FL153           Томск (Богашево)                   Абакан
# 1              FL374                    Иркутск                  Магадан
# 2              FL189  Санкт-Петербург (Пулково)                   Якутск
# 3              FL887                  Остафьево  Красноярск (Емельяново)
# 4              FL517             Ханты-Мансийск    Нижнекамск (Бегишево)
# ...              ...                        ...                      ...
# 299995         FL919                     Элиста                Махачкала
# 299996         FL832                    Магадан       Тобольск (Ремезов)
# 299997         FL678     Ульяновск (Баратаевка)   Астрахань (Нариманово)
# 299998         FL682                  Махачкала  Екатеринбург (Кольцово)
# 299999         FL499       Москва (Шереметьево)                     Сочи
#
#        departure_time  departure_hour  is_weekend  season  day_of_week
# 0          2022-11-12              22           1       4            5
# 1          2022-11-12               2           1       4            5
# 2          2022-11-12              13           1       4            5
# 3          2022-11-12              13           1       4            5
# 4          2022-11-12              16           1       4            5
# ...               ...             ...         ...     ...          ...
# 299995     2022-11-12               0           1       4            5
# 299996     2022-11-12               0           1       4            5
# 299997     2022-11-12               6           1       4            5
# 299998     2022-11-12              16           1       4            5
# 299999     2022-11-12               4           1       4            5
#
# [300000 rows x 8 columns]

# %%
#данные про бронированию
total_bookings = np.random.randint(100, 250, size=n_samples)

k = 0.15  
t_0 = 30  

days_before = np.array([365, 90, 30, 14, 7, 1, 0])

booking_data = []
for total in total_bookings:
    bookings = total / (1 + np.exp(k * (days_before - t_0)))
    bookings = np.round(bookings).astype(int)
    
    noise = np.random.randint(0, 6)
    bookings += noise 

    booking_data.append(bookings)

df_booking = pd.DataFrame(booking_data, columns=[f'booking_{d}_d_before' for d in days_before])

# %%
df_booking
# Out:
#         booking_365_d_before  booking_90_d_before  booking_30_d_before  \
# 0                          1                    1                   77
# 1                          0                    0                   70
# 2                          4                    4                  110
# 3                          3                    3                   91
# 4                          5                    5                   67
# ...                      ...                  ...                  ...
# 299995                     5                    5                  107
# 299996                     1                    1                  101
# 299997                     5                    5                   93
# 299998                     1                    1                   88
# 299999                     1                    1                  100
#
#         booking_14_d_before  booking_7_d_before  booking_1_d_before  \
# 0                       141                 149                 152
# 1                       128                 136                 138
# 2                       198                 209                 213
# 3                       164                 174                 177
# 4                       120                 126                 128
# ...                     ...                 ...                 ...
# 299995                  192                 203                 206
# 299996                  184                 195                 198
# 299997                  167                 177                 180
# 299998                  161                 170                 173
# 299999                  183                 193                 196
#
#         booking_0_d_before
# 0                      152
# 1                      138
# 2                      214
# 3                      177
# 4                      129
# ...                    ...
# 299995                 207
# 299996                 199
# 299997                 180
# 299998                 173
# 299999                 197
#
# [300000 rows x 7 columns]

# %%
df = pd.concat([flights_df, df_booking], axis=1)

# %%
#данные про билетам

flights_info = {
    'percentage_cheap_fares': np.random.uniform(0.1, 0.8, n_samples), # доля невозвратных билетов
    'fare_y_avg': np.random.randint(4000, 20000, n_samples), #среднесуточная стоимость билета эконом класса за 365 дней
    'fare_j_avg': np.random.randint(30000, 70000, n_samples), #среднесуточная стоимость билета бизнес класса за 365 дней
    
    'no_show_rate_y': np.random.uniform(0.02, 0.15, n_samples), # % неявки за все года (здесь и ниже - эконом)
    'no_show_rate_year_y': np.random.uniform(0.01, 0.14, n_samples), # за последний год
    'no_show_rate_season_y': np.random.uniform(0.03, 0.16, n_samples), # за соотв. сезон
    'no_show_rate_week_y': np.random.uniform(0.02, 0.14, n_samples), # за пред.неделю
    'cancel_rate_y': np.random.uniform(0.01, 0.03, n_samples), # % отмен
    'cancel_rate_year_y': np.random.uniform(0.01, 0.03, n_samples), # за последний год
    'cancel_rate_season_y': np.random.uniform(0.01, 0.03, n_samples),
    'cancel_rate_week_y': np.random.uniform(0.02, 0.04, n_samples),

    'no_show_rate_j': np.random.uniform(0.01, 0.1, n_samples), # % неявки за все года (здесь и ниже - бизнес)
    'no_show_rate_year_j': np.random.uniform(0.01, 0.9, n_samples), # за последний год
    'no_show_rate_season_j': np.random.uniform(0.02, 0.8, n_samples), # за соотв. сезон
    'no_show_rate_week_j': np.random.uniform(0.01, 0.8, n_samples), # за пред.неделю
    'cancel_rate_j': np.random.uniform(0.01, 0.02, n_samples), # % отмен
    'cancel_rate_year_j': np.random.uniform(0.01, 0.03, n_samples), # за последний год
    'cancel_rate_season_j': np.random.uniform(0.01, 0.03, n_samples),
    'cancel_rate_week_j': np.random.uniform(0.01, 0.02, n_samples),
    
    'overbooking_rate_avg': np.random.uniform(0.03, 0.12, n_samples), #средний % овербукинга за все года
    'overbooking_rate_last_year': np.random.uniform(0.03, 0.12, n_samples), # за последний год
}

df_flights_info = pd.DataFrame(flights_info)

# %%
df = pd.concat([df, df_flights_info], axis=1)

# %%
df = df[df['departure_city'] != df['arrival_city']]

# %%
df["target"] = df["overbooking_rate_avg"] * np.random.uniform(0.8, 1.2, len(df))

df.head()
# Out:
#   flight_number             departure_city             arrival_city  \
# 0         FL153           Томск (Богашево)                   Абакан
# 1         FL374                    Иркутск                  Магадан
# 2         FL189  Санкт-Петербург (Пулково)                   Якутск
# 3         FL887                  Остафьево  Красноярск (Емельяново)
# 4         FL517             Ханты-Мансийск    Нижнекамск (Бегишево)
#
#   departure_time  departure_hour  is_weekend  season  day_of_week  \
# 0     2022-11-12              22           1       4            5
# 1     2022-11-12               2           1       4            5
# 2     2022-11-12              13           1       4            5
# 3     2022-11-12              13           1       4            5
# 4     2022-11-12              16           1       4            5
#
#    booking_365_d_before  booking_90_d_before  ...  no_show_rate_year_j  \
# 0                     1                    1  ...             0.674394
# 1                     0                    0  ...             0.495875
# 2                     4                    4  ...             0.760495
# 3                     3                    3  ...             0.685695
# 4                     5                    5  ...             0.242368
#
#    no_show_rate_season_j  no_show_rate_week_j  cancel_rate_j  \
# 0               0.476997             0.187654       0.015379
# 1               0.796406             0.126625       0.012119
# 2               0.319231             0.509361       0.015153
# 3               0.290011             0.574078       0.018985
# 4               0.069495             0.575721       0.017879
#
#    cancel_rate_year_j  cancel_rate_season_j  cancel_rate_week_j  \
# 0            0.025430              0.012389            0.016517
# 1            0.012158              0.027855            0.012245
# 2            0.017045              0.019518            0.010093
# 3            0.012502              0.016529            0.013847
# 4            0.022106              0.013723            0.012808
#
#    overbooking_rate_avg  overbooking_rate_last_year    target
# 0              0.090651                    0.075712  0.097610
# 1              0.075994                    0.069963  0.077802
# 2              0.045450                    0.074966  0.046933
# 3              0.040517                    0.037269  0.035680
# 4              0.107953                    0.110926  0.125383
#
# [5 rows x 37 columns]

# %%
# !pip install -U lightautoml
#!pip install --upgrade pip

# %%
import torch
from lightautoml.automl.presets.tabular_presets import TabularUtilizedAutoML

from lightautoml.tasks import Task
import os
import time

# %%
N_THREADS = 4
N_FOLDS = 7
RANDOM_STATE = 123
TIMEOUT = 60 * 5 #should be increased in reality!
TARGET_NAME = 'target'

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    
seed_everything(RANDOM_STATE)

# %%
torch.set_num_threads(N_THREADS)

# %%
tr_data, te_data = train_test_split(
    df,
    test_size=0.2, 
    random_state=RANDOM_STATE
)

print(f'Data splitted. Parts sizes: tr_data = {tr_data.shape}, te_data = {te_data.shape}')

tr_data.head()
# Out:
# Data splitted. Parts sizes: tr_data = (237157, 37), te_data = (59290, 37)
#        flight_number              departure_city            arrival_city  \
# 173689         FL501            Самара (Курумоч)  Петрозаводск (Бесовец)
# 295554         FL426                 Симферополь                  Курган
# 158074         FL382                   Сыктывкар        Самара (Курумоч)
# 7293           FL622  Нижний Новгород (Стригино)      Анадырь (Угольный)
# 230018         FL213            Анапа (Витязево)    Москва (Шереметьево)
#
#        departure_time  departure_hour  is_weekend  season  day_of_week  \
# 173689     2022-11-12               6           1       4            5
# 295554     2022-11-12              16           1       4            5
# 158074     2022-11-12               7           1       4            5
# 7293       2022-11-12              17           1       4            5
# 230018     2022-11-12               6           1       4            5
#
#         booking_365_d_before  booking_90_d_before  ...  no_show_rate_year_j  \
# 173689                     5                    5  ...             0.508466
# 295554                     4                    4  ...             0.079090
# 158074                     2                    2  ...             0.676708
# 7293                       3                    3  ...             0.139340
# 230018                     1                    1  ...             0.324539
#
#         no_show_rate_season_j  no_show_rate_week_j  cancel_rate_j  \
# 173689               0.353778             0.199197       0.010542
# 295554               0.038437             0.453731       0.012124
# 158074               0.654318             0.525856       0.015391
# 7293                 0.235491             0.105949       0.011155
# 230018               0.618677             0.732255       0.010525
#
#         cancel_rate_year_j  cancel_rate_season_j  cancel_rate_week_j  \
# 173689            0.022062              0.024910            0.017925
# 295554            0.017443              0.018762            0.016967
# 158074            0.026522              0.016948            0.017826
# 7293              0.016006              0.021225            0.017976
# 230018            0.024324              0.025411            0.013208
#
#         overbooking_rate_avg  overbooking_rate_last_year    target
# 173689              0.099343                    0.084563  0.116684
# 295554              0.038460                    0.085713  0.040672
# 158074              0.071445                    0.078354  0.064100
# 7293                0.103985                    0.083686  0.090278
# 230018              0.077217                    0.032084  0.088303
#
# [5 rows x 37 columns]

# %%
task = Task(
    'reg', 
    loss='mse',
    metric='mae'
)

# %%
roles = {
    'target': TARGET_NAME,
    'category': ['departure_city', 'arrival_city', 'is_weekend', 'season', 'day_of_week'],
    'date': ['departure_time'],
    'drop': ['flight_number	']
}

# %%
utilized_automl = TabularUtilizedAutoML(
    task=task,
    timeout=TIMEOUT,
    cpu_limit=N_THREADS,
    reader_params={'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
)

# %%
# %%time 
oof_pred = utilized_automl.fit_predict(tr_data, roles=roles, verbose=3)
# Out:
# [21:31:35] Start automl utilizator with listed constraints:
# [21:31:35] - time: 300.00 seconds
# [21:31:35] - CPU: 4 cores
# [21:31:35] - memory: 16 GB
#
# [21:31:35] If one preset completes earlier, next preset configuration will be started
#
# [21:31:35] ==================================================
# [21:31:35] Start 0 automl preset configuration:
# [21:31:35] C:\Users\Legion\anaconda3\Lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_0_sel_type_0.yml, random state: {'reader_params': {'random_state': 42}, 'nn_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# [21:31:35] Found reader_params in kwargs, need to combine
# [21:31:35] Merged variant for reader_params = {'n_jobs': 4, 'cv': 7, 'random_state': 42}
# [21:31:35] Stdout logging level is INFO3.
# [21:31:35] Task: reg
#
# [21:31:35] Start automl preset with listed constraints:
# [21:31:35] - time: 300.00 seconds
# [21:31:35] - CPU: 4 cores
# [21:31:35] - memory: 16 GB
#
# [21:31:35] Train data shape: (237157, 37)
#
# [21:31:43] Feats was rejected during automatic roles guess: []
# [21:31:43] Layer 1 train process start. Time left 292.22 secs
# C:\Users\Legion\anaconda3\Lib\site-packages\numpy\lib\nanfunctions.py:1217: RuntimeWarning: All-NaN slice encountered
#   return function_base._ureduce(a, func=_nanmedian, keepdims=keepdims,
# [21:31:49] Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# [21:31:49] ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [21:31:50] Linear model: C = 1e-05 score = -0.007861908570942737
# [21:31:50] Linear model: C = 5e-05 score = -0.007536912903224573
# [21:31:50] Linear model: C = 0.0001 score = -0.0075290459086676765
# [21:31:50] Linear model: C = 0.0005 score = -0.007514635241807351
# [21:31:50] Linear model: C = 0.001 score = -0.0075063824014011595
# [21:31:50] Linear model: C = 0.005 score = -0.007500615832184484
# [21:31:50] Linear model: C = 0.01 score = -0.007500615832184484
# [21:31:50] Linear model: C = 0.05 score = -0.0074969647451276905
# [21:31:50] Linear model: C = 0.1 score = -0.0074969647451276905
# [21:31:50] Linear model: C = 0.5 score = -0.0074969647451276905
# [21:31:50] ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [21:31:51] Linear model: C = 1e-05 score = -0.007811804255352643
# [21:31:51] Linear model: C = 5e-05 score = -0.007652814134367759
# [21:31:51] Linear model: C = 0.0001 score = -0.007570607332463531
# [21:31:51] Linear model: C = 0.0005 score = -0.007532439227928389
# [21:31:51] Linear model: C = 0.001 score = -0.0075061590704763835
# [21:31:51] Linear model: C = 0.005 score = -0.007488797701484684
# [21:31:51] Linear model: C = 0.01 score = -0.007477367642706047
# [21:31:51] Linear model: C = 0.05 score = -0.007469924371832255
# [21:31:51] Linear model: C = 0.1 score = -0.007465202529143314
# [21:31:51] Linear model: C = 0.5 score = -0.007465202529143314
# [21:31:51] Linear model: C = 1 score = -0.007465202529143314
# [21:31:51] ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [21:31:52] Linear model: C = 1e-05 score = -0.007825643211140673
# [21:31:52] Linear model: C = 5e-05 score = -0.007668739514766738
# [21:31:52] Linear model: C = 0.0001 score = -0.007588961070624136
# [21:31:52] Linear model: C = 0.0005 score = -0.00755147953790258
# [21:31:52] Linear model: C = 0.001 score = -0.007526616781861081
# [21:31:52] Linear model: C = 0.005 score = -0.007510256089075542
# [21:31:52] Linear model: C = 0.01 score = -0.007499460753591288
# [21:31:52] Linear model: C = 0.05 score = -0.007492435093573739
# [21:31:52] Linear model: C = 0.1 score = -0.00748798511625084
# [21:31:52] Linear model: C = 0.5 score = -0.00748798511625084
# [21:31:52] Linear model: C = 1 score = -0.00748798511625084
# [21:31:52] ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [21:31:52] Linear model: C = 1e-05 score = -0.007801379548128914
# [21:31:52] Linear model: C = 5e-05 score = -0.007645057832962427
# [21:31:52] Linear model: C = 0.0001 score = -0.007564392625986543
# [21:31:52] Linear model: C = 0.0005 score = -0.007530596068288584
# [21:31:52] Linear model: C = 0.001 score = -0.007504894253042115
# [21:31:53] Linear model: C = 0.005 score = -0.007488303919035369
# [21:31:53] Linear model: C = 0.01 score = -0.007477649334047698
# [21:31:53] Linear model: C = 0.05 score = -0.007470754216905008
# [21:31:53] Linear model: C = 0.1 score = -0.007466094821348281
# [21:31:53] Linear model: C = 0.5 score = -0.007466094821348281
# [21:31:53] Linear model: C = 1 score = -0.007466094821348281
# [21:31:53] ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [21:31:53] Linear model: C = 1e-05 score = -0.007854836941436552
# [21:31:53] Linear model: C = 5e-05 score = -0.007629788899468408
# [21:31:53] Linear model: C = 0.0001 score = -0.007571678542401015
# [21:31:53] Linear model: C = 0.0005 score = -0.007537804153758492
# [21:31:53] Linear model: C = 0.001 score = -0.0075167102568883355
# [21:31:53] Linear model: C = 0.005 score = -0.007502528464956149
# [21:31:53] Linear model: C = 0.01 score = -0.007493484911597369
# [21:31:53] Linear model: C = 0.05 score = -0.007487679514071634
# [21:31:53] Linear model: C = 0.1 score = -0.007487679514071634
# [21:31:53] Linear model: C = 0.5 score = -0.007487679514071634
# [21:31:53] ===== Start working with fold 5 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [21:31:54] Linear model: C = 1e-05 score = -0.007873800729821015
# [21:31:54] Linear model: C = 5e-05 score = -0.007717465792407951
# [21:31:54] Linear model: C = 0.0001 score = -0.007635139707091644
# [21:31:54] Linear model: C = 0.0005 score = -0.007595128953952405
# [21:31:54] Linear model: C = 0.001 score = -0.0075684441392302555
# [21:31:54] Linear model: C = 0.005 score = -0.007550697488139559
# [21:31:54] Linear model: C = 0.01 score = -0.007539177050085098
# [21:31:54] Linear model: C = 0.05 score = -0.007531464930990642
# [21:31:54] Linear model: C = 0.1 score = -0.007526334699415311
# [21:31:54] Linear model: C = 0.5 score = -0.007526334699415311
# [21:31:54] Linear model: C = 1 score = -0.007526334699415311
# [21:31:54] ===== Start working with fold 6 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# [21:31:54] Linear model: C = 1e-05 score = -0.007841379034860754
# [21:31:55] Linear model: C = 5e-05 score = -0.0076922935964175605
# [21:31:55] Linear model: C = 0.0001 score = -0.007616213283076542
# [21:31:55] Linear model: C = 0.0005 score = -0.007580475346386176
# [21:31:55] Linear model: C = 0.001 score = -0.007557538095880827
# [21:31:55] Linear model: C = 0.005 score = -0.007542772048979142
# [21:31:55] Linear model: C = 0.01 score = -0.007533618990216942
# [21:31:55] Linear model: C = 0.05 score = -0.0075279964032630535
# [21:31:55] Linear model: C = 0.1 score = -0.0075244874403754235
# [21:31:55] Linear model: C = 0.5 score = -0.0075244874403754235
# [21:31:55] Linear model: C = 1 score = -0.0075244874403754235
# [21:31:55] Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -0.0074935353081265295
# [21:31:55] Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# [21:31:55] Time left 280.00 secs
#
# [21:32:01] Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# [21:32:01] ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [21:32:02] Training until validation scores don't improve for 100 rounds
# [21:32:02] [100]	valid's l1: 0.00752541
# [21:32:03] [200]	valid's l1: 0.00749894
# [21:32:03] Early stopping, best iteration is:
# [171]	valid's l1: 0.00749832
# [21:32:03] ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [21:32:04] Training until validation scores don't improve for 100 rounds
# [21:32:04] [100]	valid's l1: 0.007495
# [21:32:05] [200]	valid's l1: 0.00746159
# [21:32:05] [300]	valid's l1: 0.00746192
# [21:32:06] Early stopping, best iteration is:
# [243]	valid's l1: 0.00746113
# [21:32:06] ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [21:32:06] Training until validation scores don't improve for 100 rounds
# [21:32:06] [100]	valid's l1: 0.00751533
# [21:32:07] [200]	valid's l1: 0.00748416
# [21:32:08] [300]	valid's l1: 0.00748402
# [21:32:08] Early stopping, best iteration is:
# [222]	valid's l1: 0.00748355
# [21:32:08] ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [21:32:08] Training until validation scores don't improve for 100 rounds
# [21:32:08] [100]	valid's l1: 0.00749322
# [21:32:09] [200]	valid's l1: 0.00746232
# [21:32:10] [300]	valid's l1: 0.00746281
# [21:32:10] Early stopping, best iteration is:
# [238]	valid's l1: 0.0074619
# [21:32:10] ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [21:32:10] Training until validation scores don't improve for 100 rounds
# [21:32:11] [100]	valid's l1: 0.00751046
# [21:32:11] [200]	valid's l1: 0.00747898
# [21:32:12] [300]	valid's l1: 0.00748061
# [21:32:12] Early stopping, best iteration is:
# [201]	valid's l1: 0.00747884
# [21:32:12] ===== Start working with fold 5 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [21:32:12] Training until validation scores don't improve for 100 rounds
# [21:32:13] [100]	valid's l1: 0.00755602
# [21:32:13] [200]	valid's l1: 0.0075215
# [21:32:14] Early stopping, best iteration is:
# [172]	valid's l1: 0.00752099
# [21:32:14] ===== Start working with fold 6 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# [21:32:14] Training until validation scores don't improve for 100 rounds
# [21:32:14] [100]	valid's l1: 0.00754891
# [21:32:15] [200]	valid's l1: 0.00752454
# [21:32:15] Early stopping, best iteration is:
# [175]	valid's l1: 0.00752402
# [21:32:15] Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -0.007489819269056568
# [21:32:15] Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# [21:32:15] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 16.39 secs
# [21:32:15] Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# [21:32:16] Training until validation scores don't improve for 100 rounds
# [21:32:17] [100]	valid's l1: 0.0076078
# [21:32:17] [200]	valid's l1: 0.00751216
# [21:32:18] Early stopping, best iteration is:
# [187]	valid's l1: 0.00751035
# [21:32:18] Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -0.007510345123789669 in 0:00:02.567510
# [21:32:18] Training until validation scores don't improve for 100 rounds
# [21:32:19] [100]	valid's l1: 0.00778108
# [21:32:20] [200]	valid's l1: 0.00751783
# [21:32:20] [300]	valid's l1: 0.00751244
# [21:32:21] Early stopping, best iteration is:
# [267]	valid's l1: 0.00751149
# [21:32:21] Trial 2 with hyperparameters {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285} scored -0.007511490872279533 in 0:00:02.805881
# [21:32:21] Training until validation scores don't improve for 100 rounds
# [21:32:22] [100]	valid's l1: 0.00752353
# [21:32:22] [200]	valid's l1: 0.0075013
# [21:32:22] Early stopping, best iteration is:
# [173]	valid's l1: 0.00750032
# [21:32:22] Trial 3 with hyperparameters {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323} scored -0.007500320772837716 in 0:00:01.599185
# [21:32:23] Training until validation scores don't improve for 100 rounds
# [21:32:23] [100]	valid's l1: 0.00759832
# [21:32:24] [200]	valid's l1: 0.00750339
# [21:32:24] Early stopping, best iteration is:
# [199]	valid's l1: 0.00750327
# [21:32:24] Trial 4 with hyperparameters {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05} scored -0.007503266504854451 in 0:00:01.736546
# [21:32:25] Training until validation scores don't improve for 100 rounds
# [21:32:25] [100]	valid's l1: 0.00758532
# [21:32:26] [200]	valid's l1: 0.00751487
# [21:32:26] Early stopping, best iteration is:
# [157]	valid's l1: 0.00751191
# [21:32:27] Trial 5 with hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08} scored -0.00751191294776872 in 0:00:02.385079
# [21:32:27] Training until validation scores don't improve for 100 rounds
# [21:32:27] [100]	valid's l1: 0.00758912
# [21:32:27] [200]	valid's l1: 0.00750628
# [21:32:28] [300]	valid's l1: 0.00750285
# [21:32:28] [400]	valid's l1: 0.00750208
# [21:32:28] [500]	valid's l1: 0.00750189
# [21:32:28] [600]	valid's l1: 0.00750166
# [21:32:28] [700]	valid's l1: 0.00750149
# [21:32:28] [800]	valid's l1: 0.00750134
# [21:32:29] [900]	valid's l1: 0.00750125
# [21:32:29] [1000]	valid's l1: 0.00750118
# [21:32:29] [1100]	valid's l1: 0.00750112
# [21:32:29] [1200]	valid's l1: 0.00750108
# [21:32:29] [1300]	valid's l1: 0.00750091
# [21:32:29] [1400]	valid's l1: 0.00750088
# [21:32:29] [1500]	valid's l1: 0.0075007
# [21:32:30] [1600]	valid's l1: 0.00750061
# [21:32:30] [1700]	valid's l1: 0.0075005
# [21:32:30] [1800]	valid's l1: 0.00750043
# [21:32:30] [1900]	valid's l1: 0.00750032
# [21:32:30] [2000]	valid's l1: 0.00750025
# [21:32:30] Did not meet early stopping. Best iteration is:
# [2000]	valid's l1: 0.00750025
# [21:32:31] Trial 6 with hyperparameters {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936} scored -0.0075002518376711 in 0:00:03.930870
# [21:32:31] Training until validation scores don't improve for 100 rounds
# [21:32:31] [100]	valid's l1: 0.00760147
# [21:32:32] [200]	valid's l1: 0.00749917
# [21:32:32] Early stopping, best iteration is:
# [183]	valid's l1: 0.00749869
# [21:32:32] Trial 7 with hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574} scored -0.007498690773750339 in 0:00:01.393043
# [21:32:32] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# [21:32:32] The set of hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574}
#  achieve -0.0075 mae
# [21:32:32] Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# [21:32:32] ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [21:32:32] Training until validation scores don't improve for 100 rounds
# [21:32:33] [100]	valid's l1: 0.0075218
# [21:32:33] [200]	valid's l1: 0.00749843
# [21:32:33] Early stopping, best iteration is:
# [155]	valid's l1: 0.00749749
# [21:32:33] ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [21:32:33] Training until validation scores don't improve for 100 rounds
# [21:32:34] [100]	valid's l1: 0.00748933
# [21:32:34] [200]	valid's l1: 0.00746219
# [21:32:34] Early stopping, best iteration is:
# [157]	valid's l1: 0.00746114
# [21:32:35] ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [21:32:35] Training until validation scores don't improve for 100 rounds
# [21:32:35] [100]	valid's l1: 0.0075133
# [21:32:36] [200]	valid's l1: 0.0074902
# [21:32:36] [300]	valid's l1: 0.0074903
# [21:32:36] Early stopping, best iteration is:
# [254]	valid's l1: 0.00748953
# [21:32:36] ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [21:32:36] Training until validation scores don't improve for 100 rounds
# [21:32:37] [100]	valid's l1: 0.00748887
# [21:32:37] [200]	valid's l1: 0.00746125
# [21:32:37] Early stopping, best iteration is:
# [175]	valid's l1: 0.00746082
# [21:32:37] ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [21:32:38] Training until validation scores don't improve for 100 rounds
# [21:32:38] [100]	valid's l1: 0.00750637
# [21:32:38] [200]	valid's l1: 0.00748181
# [21:32:39] Early stopping, best iteration is:
# [157]	valid's l1: 0.00748073
# [21:32:39] ===== Start working with fold 5 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [21:32:39] Training until validation scores don't improve for 100 rounds
# [21:32:39] [100]	valid's l1: 0.00754976
# [21:32:40] [200]	valid's l1: 0.0075199
# [21:32:40] [300]	valid's l1: 0.00752174
# [21:32:40] Early stopping, best iteration is:
# [220]	valid's l1: 0.00751947
# [21:32:40] ===== Start working with fold 6 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# [21:32:40] Training until validation scores don't improve for 100 rounds
# [21:32:41] [100]	valid's l1: 0.00754408
# [21:32:41] [200]	valid's l1: 0.0075247
# [21:32:41] Early stopping, best iteration is:
# [172]	valid's l1: 0.00752398
# [21:32:41] Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -0.007490453196614795
# [21:32:41] Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# [21:32:41] Start fitting Lvl_0_Pipe_1_Mod_2_CatBoost ...
# [21:32:41] ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
# [21:32:42] 0:	learn: 0.0223175	test: 0.0222537	best: 0.0222537 (0)	total: 111ms	remaining: 3m 42s
# [21:32:43] 100:	learn: 0.0075116	test: 0.0075178	best: 0.0075178 (100)	total: 1.24s	remaining: 23.3s
# [21:32:44] 200:	learn: 0.0074991	test: 0.0075139	best: 0.0075137 (178)	total: 2.25s	remaining: 20.1s
# [21:32:45] 300:	learn: 0.0074887	test: 0.0075138	best: 0.0075137 (218)	total: 3.25s	remaining: 18.3s
# [21:32:46] 400:	learn: 0.0074773	test: 0.0075140	best: 0.0075137 (218)	total: 4.21s	remaining: 16.8s
# [21:32:47] 500:	learn: 0.0074663	test: 0.0075145	best: 0.0075137 (218)	total: 5.15s	remaining: 15.4s
# [21:32:47] Stopped by overfitting detector  (300 iterations wait)
# [21:32:47] bestTest = 0.007513697687
# [21:32:47] bestIteration = 218
# [21:32:47] Shrink model to first 219 iterations.
# [21:32:47] ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
# [21:32:48] 0:	learn: 0.0223072	test: 0.0223212	best: 0.0223212 (0)	total: 12.5ms	remaining: 25s
# [21:32:49] 100:	learn: 0.0075168	test: 0.0074909	best: 0.0074909 (100)	total: 1.06s	remaining: 20s
# [21:32:50] 200:	learn: 0.0075043	test: 0.0074859	best: 0.0074859 (200)	total: 2.03s	remaining: 18.2s
# [21:32:51] 300:	learn: 0.0074936	test: 0.0074854	best: 0.0074848 (257)	total: 2.97s	remaining: 16.8s
# [21:32:51] 400:	learn: 0.0074821	test: 0.0074857	best: 0.0074848 (257)	total: 3.89s	remaining: 15.5s
# [21:32:52] 500:	learn: 0.0074715	test: 0.0074861	best: 0.0074848 (257)	total: 4.82s	remaining: 14.4s
# [21:32:53] Stopped by overfitting detector  (300 iterations wait)
# [21:32:53] bestTest = 0.007484766315
# [21:32:53] bestIteration = 257
# [21:32:53] Shrink model to first 258 iterations.
# [21:32:53] ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
# [21:32:53] 0:	learn: 0.0223030	test: 0.0223359	best: 0.0223359 (0)	total: 12ms	remaining: 24s
# [21:32:54] 100:	learn: 0.0075129	test: 0.0075080	best: 0.0075080 (100)	total: 1.02s	remaining: 19.2s
# [21:32:55] 200:	learn: 0.0075009	test: 0.0075031	best: 0.0075027 (173)	total: 1.96s	remaining: 17.5s
# [21:32:56] 300:	learn: 0.0074908	test: 0.0075034	best: 0.0075027 (173)	total: 2.88s	remaining: 16.3s
# [21:32:57] 400:	learn: 0.0074788	test: 0.0075048	best: 0.0075027 (173)	total: 3.82s	remaining: 15.2s
# [21:32:58] Stopped by overfitting detector  (300 iterations wait)
# [21:32:58] bestTest = 0.007502742335
# [21:32:58] bestIteration = 173
# [21:32:58] Shrink model to first 174 iterations.
# [21:32:58] ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
# [21:32:58] 0:	learn: 0.0223279	test: 0.0221964	best: 0.0221964 (0)	total: 13.3ms	remaining: 26.6s
# [21:32:59] 100:	learn: 0.0075185	test: 0.0074902	best: 0.0074902 (100)	total: 1.08s	remaining: 20.4s
# [21:33:00] 200:	learn: 0.0075063	test: 0.0074846	best: 0.0074846 (197)	total: 2.07s	remaining: 18.5s
# [21:33:01] 300:	learn: 0.0074963	test: 0.0074835	best: 0.0074833 (278)	total: 3.01s	remaining: 17s
# [21:33:02] 400:	learn: 0.0074849	test: 0.0074841	best: 0.0074833 (278)	total: 3.92s	remaining: 15.6s
# [21:33:03] 500:	learn: 0.0074742	test: 0.0074842	best: 0.0074833 (278)	total: 4.83s	remaining: 14.5s
# [21:33:04] Stopped by overfitting detector  (300 iterations wait)
# [21:33:04] bestTest = 0.007483310923
# [21:33:04] bestIteration = 278
# [21:33:04] Shrink model to first 279 iterations.
# [21:33:04] ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
# [21:33:04] 0:	learn: 0.0223207	test: 0.0223063	best: 0.0223063 (0)	total: 12.2ms	remaining: 24.5s
# [21:33:05] 100:	learn: 0.0075145	test: 0.0075023	best: 0.0075023 (100)	total: 1.02s	remaining: 19.2s
# [21:33:06] 200:	learn: 0.0075025	test: 0.0074977	best: 0.0074975 (170)	total: 1.96s	remaining: 17.5s
# [21:33:07] 300:	learn: 0.0074923	test: 0.0074974	best: 0.0074972 (225)	total: 2.88s	remaining: 16.3s
# [21:33:08] 400:	learn: 0.0074809	test: 0.0074980	best: 0.0074972 (314)	total: 3.81s	remaining: 15.2s
# [21:33:09] 500:	learn: 0.0074694	test: 0.0074981	best: 0.0074972 (314)	total: 4.73s	remaining: 14.2s
# [21:33:10] 600:	learn: 0.0074585	test: 0.0074980	best: 0.0074972 (314)	total: 5.65s	remaining: 13.2s
# [21:33:10] Stopped by overfitting detector  (300 iterations wait)
# [21:33:10] bestTest = 0.007497159407
# [21:33:10] bestIteration = 314
# [21:33:10] Shrink model to first 315 iterations.
# [21:33:10] ===== Start working with fold 5 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
# [21:33:10] 0:	learn: 0.0222938	test: 0.0224439	best: 0.0224439 (0)	total: 11.6ms	remaining: 23.2s
# [21:33:11] 100:	learn: 0.0075074	test: 0.0075508	best: 0.0075508 (100)	total: 995ms	remaining: 18.7s
# [21:33:12] 200:	learn: 0.0074957	test: 0.0075458	best: 0.0075453 (184)	total: 1.92s	remaining: 17.2s
# [21:33:13] 300:	learn: 0.0074849	test: 0.0075452	best: 0.0075450 (282)	total: 2.83s	remaining: 15.9s
# [21:33:14] 400:	learn: 0.0074732	test: 0.0075451	best: 0.0075446 (333)	total: 3.72s	remaining: 14.8s
# [21:33:15] 500:	learn: 0.0074624	test: 0.0075448	best: 0.0075446 (333)	total: 4.62s	remaining: 13.8s
# [21:33:16] 600:	learn: 0.0074520	test: 0.0075453	best: 0.0075446 (333)	total: 5.53s	remaining: 12.9s
# [21:33:16] Stopped by overfitting detector  (300 iterations wait)
# [21:33:16] bestTest = 0.007544600197
# [21:33:16] bestIteration = 333
# [21:33:16] Shrink model to first 334 iterations.
# [21:33:16] ===== Start working with fold 6 for Lvl_0_Pipe_1_Mod_2_CatBoost =====
# [21:33:16] 0:	learn: 0.0223151	test: 0.0223295	best: 0.0223295 (0)	total: 11.6ms	remaining: 23.3s
# [21:33:17] 100:	learn: 0.0075078	test: 0.0075471	best: 0.0075471 (100)	total: 1.02s	remaining: 19.1s
# [21:33:18] 200:	learn: 0.0074958	test: 0.0075437	best: 0.0075436 (198)	total: 2s	remaining: 17.9s
# [21:33:19] 300:	learn: 0.0074852	test: 0.0075439	best: 0.0075432 (248)	total: 2.9s	remaining: 16.4s
# [21:33:20] 400:	learn: 0.0074734	test: 0.0075444	best: 0.0075432 (248)	total: 3.81s	remaining: 15.2s
# [21:33:21] 500:	learn: 0.0074621	test: 0.0075454	best: 0.0075432 (248)	total: 4.75s	remaining: 14.2s
# [21:33:21] Stopped by overfitting detector  (300 iterations wait)
# [21:33:21] bestTest = 0.007543193137
# [21:33:21] bestIteration = 248
# [21:33:21] Shrink model to first 249 iterations.
# [21:33:21] Fitting Lvl_0_Pipe_1_Mod_2_CatBoost finished. score = -0.0075109240025088495
# [21:33:21] Lvl_0_Pipe_1_Mod_2_CatBoost fitting and predicting completed
# [21:33:21] Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ... Time budget is 34.60 secs
# [21:33:22] 0:	learn: 0.0223400	test: 0.0222786	best: 0.0222786 (0)	total: 10.8ms	remaining: 21.6s
# [21:33:23] 100:	learn: 0.0075158	test: 0.0075182	best: 0.0075182 (100)	total: 916ms	remaining: 17.2s
# [21:33:24] 200:	learn: 0.0075063	test: 0.0075135	best: 0.0075135 (200)	total: 1.74s	remaining: 15.6s
# [21:33:24] 300:	learn: 0.0075001	test: 0.0075134	best: 0.0075134 (297)	total: 2.55s	remaining: 14.4s
# [21:33:25] 400:	learn: 0.0074937	test: 0.0075138	best: 0.0075134 (297)	total: 3.36s	remaining: 13.4s
# [21:33:26] 500:	learn: 0.0074869	test: 0.0075144	best: 0.0075134 (297)	total: 4.16s	remaining: 12.5s
# [21:33:27] Stopped by overfitting detector  (300 iterations wait)
# [21:33:27] bestTest = 0.007513360195
# [21:33:27] bestIteration = 297
# [21:33:27] Shrink model to first 298 iterations.
# [21:33:27] Trial 1 with hyperparameters {'max_depth': 4, 'nan_mode': 'Max', 'l2_leaf_reg': 0.0024430162614261413, 'min_data_in_leaf': 4} scored -0.007514360167610443 in 0:00:05.349057
# [21:33:27] 0:	learn: 0.0223687	test: 0.0223038	best: 0.0223038 (0)	total: 8.97ms	remaining: 17.9s
# [21:33:28] 100:	learn: 0.0075174	test: 0.0075210	best: 0.0075210 (100)	total: 776ms	remaining: 14.6s
# [21:33:29] 200:	learn: 0.0075079	test: 0.0075143	best: 0.0075143 (200)	total: 1.48s	remaining: 13.3s
# [21:33:29] 300:	learn: 0.0075045	test: 0.0075142	best: 0.0075142 (297)	total: 2.16s	remaining: 12.2s
# [21:33:30] 400:	learn: 0.0075010	test: 0.0075145	best: 0.0075142 (302)	total: 2.84s	remaining: 11.3s
# [21:33:31] 500:	learn: 0.0074978	test: 0.0075149	best: 0.0075142 (302)	total: 3.5s	remaining: 10.5s
# [21:33:31] 600:	learn: 0.0074946	test: 0.0075148	best: 0.0075142 (302)	total: 4.2s	remaining: 9.77s
# [21:33:31] Stopped by overfitting detector  (300 iterations wait)
# [21:33:31] bestTest = 0.007514202764
# [21:33:31] bestIteration = 302
# [21:33:31] Shrink model to first 303 iterations.
# [21:33:31] Trial 2 with hyperparameters {'max_depth': 3, 'nan_mode': 'Min', 'l2_leaf_reg': 0.002570603566117598, 'min_data_in_leaf': 15} scored -0.007515202774149333 in 0:00:04.590915
# [21:33:32] 0:	learn: 0.0223733	test: 0.0223126	best: 0.0223126 (0)	total: 9.09ms	remaining: 18.2s
# [21:33:33] 100:	learn: 0.0075169	test: 0.0075209	best: 0.0075209 (100)	total: 802ms	remaining: 15.1s
# [21:33:33] 200:	learn: 0.0075082	test: 0.0075149	best: 0.0075148 (199)	total: 1.57s	remaining: 14s
# [21:33:34] 300:	learn: 0.0075047	test: 0.0075147	best: 0.0075146 (297)	total: 2.29s	remaining: 12.9s
# [21:33:35] 400:	learn: 0.0075013	test: 0.0075146	best: 0.0075145 (384)	total: 3s	remaining: 12s
# [21:33:35] 500:	learn: 0.0074981	test: 0.0075143	best: 0.0075143 (500)	total: 3.71s	remaining: 11.1s
# [21:33:36] 600:	learn: 0.0074947	test: 0.0075143	best: 0.0075143 (590)	total: 4.41s	remaining: 10.3s
# [21:33:37] 700:	learn: 0.0074918	test: 0.0075143	best: 0.0075141 (688)	total: 5.14s	remaining: 9.52s
# [21:33:38] 800:	learn: 0.0074888	test: 0.0075144	best: 0.0075141 (688)	total: 5.84s	remaining: 8.74s
# [21:33:38] 900:	learn: 0.0074860	test: 0.0075146	best: 0.0075141 (688)	total: 6.55s	remaining: 8s
# [21:33:39] Stopped by overfitting detector  (300 iterations wait)
# [21:33:39] bestTest = 0.007514113157
# [21:33:39] bestIteration = 688
# [21:33:39] Shrink model to first 689 iterations.
# [21:33:39] Trial 3 with hyperparameters {'max_depth': 3, 'nan_mode': 'Max', 'l2_leaf_reg': 8.148018307012941e-07, 'min_data_in_leaf': 4} scored -0.00751511316567808 in 0:00:07.564550
# [21:33:39] 0:	learn: 0.0223687	test: 0.0223038	best: 0.0223038 (0)	total: 8.83ms	remaining: 17.7s
# [21:33:40] 100:	learn: 0.0075174	test: 0.0075210	best: 0.0075210 (100)	total: 790ms	remaining: 14.8s
# [21:33:41] 200:	learn: 0.0075079	test: 0.0075143	best: 0.0075143 (200)	total: 1.5s	remaining: 13.4s
# [21:33:42] 300:	learn: 0.0075045	test: 0.0075142	best: 0.0075142 (297)	total: 2.18s	remaining: 12.3s
# [21:33:42] 400:	learn: 0.0075010	test: 0.0075145	best: 0.0075142 (302)	total: 2.85s	remaining: 11.4s
# [21:33:43] 500:	learn: 0.0074978	test: 0.0075149	best: 0.0075142 (302)	total: 3.51s	remaining: 10.5s
# [21:33:44] 600:	learn: 0.0074946	test: 0.0075148	best: 0.0075142 (302)	total: 4.19s	remaining: 9.74s
# [21:33:44] Stopped by overfitting detector  (300 iterations wait)
# [21:33:44] bestTest = 0.00751420277
# [21:33:44] bestIteration = 302
# [21:33:44] Shrink model to first 303 iterations.
# [21:33:44] Trial 4 with hyperparameters {'max_depth': 3, 'nan_mode': 'Min', 'l2_leaf_reg': 7.71800699380605e-05, 'min_data_in_leaf': 6} scored -0.007515202786079498 in 0:00:04.580113
# [21:33:44] 0:	learn: 0.0223175	test: 0.0222537	best: 0.0222537 (0)	total: 12.3ms	remaining: 24.6s
# [21:33:45] 100:	learn: 0.0075100	test: 0.0075171	best: 0.0075171 (100)	total: 1.12s	remaining: 21.1s
# [21:33:46] 200:	learn: 0.0074910	test: 0.0075130	best: 0.0075126 (163)	total: 2.14s	remaining: 19.2s
# [21:33:47] 300:	learn: 0.0074729	test: 0.0075141	best: 0.0075126 (163)	total: 3.14s	remaining: 17.7s
# [21:33:48] 400:	learn: 0.0074521	test: 0.0075144	best: 0.0075126 (163)	total: 4.13s	remaining: 16.5s
# [21:33:49] Stopped by overfitting detector  (300 iterations wait)
# [21:33:49] bestTest = 0.00751263632
# [21:33:49] bestIteration = 163
# [21:33:49] Shrink model to first 164 iterations.
# [21:33:49] Trial 5 with hyperparameters {'max_depth': 6, 'nan_mode': 'Min', 'l2_leaf_reg': 1.9826980964985924e-05, 'min_data_in_leaf': 10} scored -0.00751363627501018 in 0:00:05.151209
# [21:33:49] 0:	learn: 0.0223175	test: 0.0222537	best: 0.0222537 (0)	total: 13.7ms	remaining: 27.4s
# [21:33:50] 100:	learn: 0.0075100	test: 0.0075171	best: 0.0075171 (100)	total: 1.12s	remaining: 21.1s
# [21:33:51] 200:	learn: 0.0074910	test: 0.0075130	best: 0.0075126 (163)	total: 2.15s	remaining: 19.2s
# [21:33:52] 300:	learn: 0.0074729	test: 0.0075141	best: 0.0075126 (163)	total: 3.15s	remaining: 17.8s
# [21:33:53] 400:	learn: 0.0074521	test: 0.0075144	best: 0.0075126 (163)	total: 4.13s	remaining: 16.5s
# [21:33:54] Stopped by overfitting detector  (300 iterations wait)
# [21:33:54] bestTest = 0.007512636298
# [21:33:54] bestIteration = 163
# [21:33:54] Shrink model to first 164 iterations.
# [21:33:54] Trial 6 with hyperparameters {'max_depth': 6, 'nan_mode': 'Min', 'l2_leaf_reg': 0.0021465011216654484, 'min_data_in_leaf': 1} scored -0.007513636266873477 in 0:00:05.156420
# [21:33:54] 0:	learn: 0.0223225	test: 0.0222618	best: 0.0222618 (0)	total: 12.8ms	remaining: 25.7s
# [21:33:55] 100:	learn: 0.0075098	test: 0.0075182	best: 0.0075182 (100)	total: 1.14s	remaining: 21.3s
# [21:33:56] 200:	learn: 0.0074920	test: 0.0075148	best: 0.0075144 (181)	total: 2.17s	remaining: 19.4s
# [21:33:57] 300:	learn: 0.0074748	test: 0.0075145	best: 0.0075144 (181)	total: 3.19s	remaining: 18s
# [21:33:58] 400:	learn: 0.0074556	test: 0.0075156	best: 0.0075144 (305)	total: 4.21s	remaining: 16.8s
# [21:33:59] 500:	learn: 0.0074378	test: 0.0075157	best: 0.0075144 (305)	total: 5.23s	remaining: 15.6s
# [21:34:01] 600:	learn: 0.0074192	test: 0.0075156	best: 0.0075144 (305)	total: 6.25s	remaining: 14.6s
# [21:34:01] Stopped by overfitting detector  (300 iterations wait)
# [21:34:01] bestTest = 0.007514351655
# [21:34:01] bestIteration = 305
# [21:34:01] Shrink model to first 306 iterations.
# [21:34:01] Trial 7 with hyperparameters {'max_depth': 6, 'nan_mode': 'Max', 'l2_leaf_reg': 3.4671276804481113, 'min_data_in_leaf': 20} scored -0.007515351655927068 in 0:00:06.675893
# [21:34:01] Hyperparameters optimization for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost completed
# [21:34:01] The set of hyperparameters {'max_depth': 6, 'nan_mode': 'Min', 'l2_leaf_reg': 0.0021465011216654484, 'min_data_in_leaf': 1}
#  achieve -0.0075 mae
# [21:34:01] Start fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost ...
# [21:34:01] ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# [21:34:01] 0:	learn: 0.0227429	test: 0.0226784	best: 0.0226784 (0)	total: 13.6ms	remaining: 40.8s
# [21:34:02] 100:	learn: 0.0076087	test: 0.0076107	best: 0.0076107 (100)	total: 1.17s	remaining: 33.5s
# [21:34:03] 200:	learn: 0.0075046	test: 0.0075141	best: 0.0075141 (200)	total: 2.26s	remaining: 31.4s
# [21:34:04] 300:	learn: 0.0074942	test: 0.0075126	best: 0.0075125 (292)	total: 3.3s	remaining: 29.6s
# [21:34:05] Stopped by overfitting detector  (100 iterations wait)
# [21:34:05] bestTest = 0.007512543202
# [21:34:05] bestIteration = 292
# [21:34:05] Shrink model to first 293 iterations.
# [21:34:05] ===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# [21:34:05] 0:	learn: 0.0227324	test: 0.0227466	best: 0.0227466 (0)	total: 13.9ms	remaining: 41.7s
# [21:34:07] 100:	learn: 0.0076138	test: 0.0075869	best: 0.0075869 (100)	total: 1.14s	remaining: 32.7s
# [21:34:08] 200:	learn: 0.0075097	test: 0.0074896	best: 0.0074896 (200)	total: 2.23s	remaining: 31s
# [21:34:09] 300:	learn: 0.0074992	test: 0.0074884	best: 0.0074883 (297)	total: 3.27s	remaining: 29.3s
# [21:34:10] 400:	learn: 0.0074894	test: 0.0074884	best: 0.0074881 (377)	total: 4.3s	remaining: 27.9s
# [21:34:11] Stopped by overfitting detector  (100 iterations wait)
# [21:34:11] bestTest = 0.007488137808
# [21:34:11] bestIteration = 377
# [21:34:11] Shrink model to first 378 iterations.
# [21:34:11] ===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# [21:34:11] 0:	learn: 0.0227281	test: 0.0227624	best: 0.0227624 (0)	total: 13.3ms	remaining: 39.8s
# [21:34:12] 100:	learn: 0.0076085	test: 0.0076039	best: 0.0076039 (100)	total: 1.15s	remaining: 33.1s
# [21:34:13] 200:	learn: 0.0075056	test: 0.0075032	best: 0.0075032 (199)	total: 2.24s	remaining: 31.2s
# [21:34:14] 300:	learn: 0.0074955	test: 0.0075017	best: 0.0075015 (293)	total: 3.28s	remaining: 29.4s
# [21:34:15] 400:	learn: 0.0074855	test: 0.0075015	best: 0.0075012 (378)	total: 4.31s	remaining: 27.9s
# [21:34:16] 500:	learn: 0.0074731	test: 0.0075010	best: 0.0075009 (465)	total: 5.31s	remaining: 26.5s
# [21:34:17] 600:	learn: 0.0074608	test: 0.0075011	best: 0.0075008 (529)	total: 6.34s	remaining: 25.3s
# [21:34:18] Stopped by overfitting detector  (100 iterations wait)
# [21:34:18] bestTest = 0.007500789841
# [21:34:18] bestIteration = 529
# [21:34:18] Shrink model to first 530 iterations.
# [21:34:18] ===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# [21:34:18] 0:	learn: 0.0227536	test: 0.0226202	best: 0.0226202 (0)	total: 13.1ms	remaining: 39.2s
# [21:34:19] 100:	learn: 0.0076143	test: 0.0075844	best: 0.0075844 (100)	total: 1.14s	remaining: 32.8s
# [21:34:20] 200:	learn: 0.0075110	test: 0.0074857	best: 0.0074857 (200)	total: 2.25s	remaining: 31.3s
# [21:34:21] 300:	learn: 0.0075014	test: 0.0074838	best: 0.0074838 (300)	total: 3.34s	remaining: 30s
# [21:34:22] 400:	learn: 0.0074918	test: 0.0074835	best: 0.0074834 (387)	total: 4.37s	remaining: 28.3s
# [21:34:23] 500:	learn: 0.0074795	test: 0.0074838	best: 0.0074834 (422)	total: 5.36s	remaining: 26.7s
# [21:34:23] Stopped by overfitting detector  (100 iterations wait)
# [21:34:23] bestTest = 0.00748338357
# [21:34:23] bestIteration = 422
# [21:34:23] Shrink model to first 423 iterations.
# [21:34:23] ===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# [21:34:24] 0:	learn: 0.0227424	test: 0.0227262	best: 0.0227262 (0)	total: 14.8ms	remaining: 44.5s
# [21:34:25] 100:	learn: 0.0076095	test: 0.0075976	best: 0.0075976 (100)	total: 1.17s	remaining: 33.6s
# [21:34:26] 200:	learn: 0.0075064	test: 0.0075001	best: 0.0075001 (200)	total: 2.26s	remaining: 31.5s
# [21:34:27] 300:	learn: 0.0074964	test: 0.0074987	best: 0.0074987 (300)	total: 3.3s	remaining: 29.6s
# [21:34:28] 400:	learn: 0.0074866	test: 0.0074982	best: 0.0074982 (394)	total: 4.38s	remaining: 28.4s
# [21:34:29] 500:	learn: 0.0074753	test: 0.0074988	best: 0.0074981 (404)	total: 5.41s	remaining: 27s
# [21:34:29] Stopped by overfitting detector  (100 iterations wait)
# [21:34:29] bestTest = 0.007498105612
# [21:34:29] bestIteration = 404
# [21:34:29] Shrink model to first 405 iterations.
# [21:34:29] ===== Start working with fold 5 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# [21:34:30] 0:	learn: 0.0227160	test: 0.0228667	best: 0.0228667 (0)	total: 15.5ms	remaining: 46.4s
# [21:34:31] 100:	learn: 0.0075994	test: 0.0076519	best: 0.0076519 (100)	total: 1.16s	remaining: 33.2s
# [21:34:32] 200:	learn: 0.0074996	test: 0.0075459	best: 0.0075459 (200)	total: 2.23s	remaining: 31s
# [21:34:33] 300:	learn: 0.0074893	test: 0.0075447	best: 0.0075447 (277)	total: 3.27s	remaining: 29.3s
# [21:34:34] 400:	learn: 0.0074795	test: 0.0075443	best: 0.0075443 (400)	total: 4.31s	remaining: 27.9s
# [21:34:35] 500:	learn: 0.0074676	test: 0.0075452	best: 0.0075443 (401)	total: 5.36s	remaining: 26.7s
# [21:34:35] Stopped by overfitting detector  (100 iterations wait)
# [21:34:35] bestTest = 0.007544278058
# [21:34:35] bestIteration = 401
# [21:34:35] Shrink model to first 402 iterations.
# [21:34:35] ===== Start working with fold 6 for Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost =====
# [21:34:35] 0:	learn: 0.0227366	test: 0.0227521	best: 0.0227521 (0)	total: 14ms	remaining: 42.1s
# [21:34:36] 100:	learn: 0.0076057	test: 0.0076360	best: 0.0076360 (100)	total: 1.19s	remaining: 34.1s
# [21:34:38] 200:	learn: 0.0075004	test: 0.0075453	best: 0.0075453 (198)	total: 2.3s	remaining: 32.1s
# [21:34:39] 300:	learn: 0.0074901	test: 0.0075439	best: 0.0075438 (295)	total: 3.37s	remaining: 30.2s
# [21:34:40] 400:	learn: 0.0074803	test: 0.0075442	best: 0.0075437 (330)	total: 4.42s	remaining: 28.6s
# [21:34:40] Stopped by overfitting detector  (100 iterations wait)
# [21:34:40] bestTest = 0.007543718046
# [21:34:40] bestIteration = 330
# [21:34:40] Shrink model to first 331 iterations.
# [21:34:40] Fitting Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost finished. score = -0.007511136322160237
# [21:34:40] Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost fitting and predicting completed
# [21:34:40] Time left 114.86 secs
#
# [21:34:40] Layer 1 training completed.
#
# [21:34:40] Blending: optimization starts with equal weights. Score = -0.0074907
# [21:34:40] Blending: iteration 0: score = -0.0074881, weights = [0.18708584 0.41237015 0.29179606 0.05437398 0.05437398]
# [21:34:41] Blending: no improvements for score. Terminated.
#
# [21:34:41] Blending: best score = -0.0074881, best weights = [0.18708584 0.41237015 0.29179606 0.05437398 0.05437398]
# [21:34:41] Automl preset training completed in 185.69 seconds
#
# [21:34:41] Model description:
# Final prediction for new objects (level 0) =
# 	 0.18709 * (7 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2) +
# 	 0.41237 * (7 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM) +
# 	 0.29180 * (7 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 	 0.05437 * (7 averaged models Lvl_0_Pipe_1_Mod_2_CatBoost) +
# 	 0.05437 * (7 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
#
# [21:34:41] ==================================================
# CPU times: total: 10min 26s
# Wall time: 3min 5s

# %%
print(utilized_automl.create_model_str_desc())
# Out:
# Final prediction for new objects =
# 	1.00000 * 1 averaged models with config = "C:\Users\Legion\anaconda3\Lib\site-packages\lightautoml\automl\presets\tabular_configs\conf_0_sel_type_0.yml" and different CV random_states. Their structures:
#
# 	    Model #0.
# 		================================================================================
# 		Final prediction for new objects (level 0) =
# 			 0.18709 * (7 averaged models Lvl_0_Pipe_0_Mod_0_LinearL2) +
# 			 0.41237 * (7 averaged models Lvl_0_Pipe_1_Mod_0_LightGBM) +
# 			 0.29180 * (7 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM) +
# 			 0.05437 * (7 averaged models Lvl_0_Pipe_1_Mod_2_CatBoost) +
# 			 0.05437 * (7 averaged models Lvl_0_Pipe_1_Mod_3_Tuned_CatBoost)
# 		================================================================================

# %%
te_pred = utilized_automl.predict(te_data)
print(f'Prediction for te_data:\n{te_pred}\nShape = {te_pred.shape}')
# Out:
# Prediction for te_data:
# array([[0.07460571],
#        [0.06749522],
#        [0.0423739 ],
#        ...,
#        [0.07041833],
#        [0.10908514],
#        [0.05473463]], dtype=float32)
# Shape = (59290, 1)

# %%
print(f'OOF score: {mean_absolute_error(tr_data[TARGET_NAME].values, oof_pred.data[:, 0])}')
print(f'HOLDOUT score: {mean_absolute_error(te_data[TARGET_NAME].values, te_pred.data[:, 0])}')
# Out:
# OOF score: 0.007488128631771307
# HOLDOUT score: 0.007478365193945785

# %%
#import joblib

#joblib.dump(utilized_automl, "automl_model_final.pkl")
# Out:
# ['automl_model_final.pkl']

# %% [markdown]
# Для ввода тестовых данных менеджером:

# %%
column_list = [
    'booking_365_d_before', 'booking_90_d_before', 
    'booking_30_d_before', 'booking_14_d_before', 'booking_7_d_before', 'booking_1_d_before',
    'booking_0_d_before', 'percentage_cheap_fares', 'fare_y_avg', 'fare_j_avg', 'no_show_rate_y',
    'no_show_rate_year_y', 'no_show_rate_season_y', 'no_show_rate_week_y', 'cancel_rate_y', 
    'cancel_rate_year_y', 'cancel_rate_season_y', 'cancel_rate_week_y', 'no_show_rate_j', 
    'no_show_rate_year_j', 'no_show_rate_season_j', 'no_show_rate_week_j', 'cancel_rate_j', 
    'cancel_rate_year_j', 'cancel_rate_season_j', 'cancel_rate_week_j', 'overbooking_rate_avg',
    'overbooking_rate_last_year'
]

# %%
def create_test_df(df, departure_city, arrival_city, departure_time, departure_hhmm, column_list):
    pair_exists = ((df['departure_city'] == departure_city) & (df['arrival_city'] == arrival_city)).any()
    
    departure_hour = int(str(departure_hhmm).zfill(4)[:2])
    
    test_df = pd.DataFrame({
        'departure_city': [departure_city],
        'arrival_city': [arrival_city],
        'departure_time': [pd.to_datetime(departure_time)],
        'departure_hhmm': [departure_hour]
    })
    
    test_df['is_weekend'] = test_df['departure_time'].dt.weekday.isin([5, 6]).astype(int)
    test_df['season'] = test_df['departure_time'].dt.month.map(lambda m: 1 if m in [12, 1, 2] else
                                                                            2 if m in [3, 4, 5] else
                                                                            3 if m in [6, 7, 8] else 4)
    test_df['day_of_week'] = test_df['departure_time'].dt.weekday
    
    # источник средних значений
    if pair_exists:
        historical_data = df[(df['departure_city'] == departure_city) & (df['arrival_city'] == arrival_city)]
    else:
        historical_data = df[df['departure_city'] == departure_city]
    
    for col in column_list:
        if col in df.columns:
            test_df[col] = historical_data[col].mean() * 0.75
    
    return test_df

# %%
te_df = create_test_df(df, departure_city, arrival_city, departure_time, departure_hhmm, column_list)

# %%
pred = utilized_automl.predict(te_df).data.flatten()
print(pred)
